# %%
QUERY_UNDERSTANDING_PROMPT = """
You are a routing assistant for the EU AI Act. Analyse the query and return JSON:

{
  "query_type": one of [
    "DEFINITIONAL",    // asks what a term means
    "OBLIGATION",      // asks what someone must do
    "CLASSIFICATION",  // asks whether something is high-risk / prohibited
    "PROCEDURAL",      // asks how to do something (register, assess, comply)
    "CROSS_CUTTING",   // spans multiple areas (GDPR, penalties, scope)
    "ANNEX_LOOKUP",    // needs a list from an annex
    "DIRECT_ARTICLE"   // explicitly asks about "Article N"
  ],
  "explicit_articles": [],   // e.g. ["Article 5", "Article 16"]
  "explicit_annexes": [],    // e.g. ["Annex III"]
  "key_terms": [],           // legal terms to search for
  "needs_recitals": true/false,   // does intent/reasoning matter?
  "needs_definitions": true/false // does Article 3 need to be fetched?
}

Query: {query}
"""

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()

OPENROUTER_API = os.getenv('OPENROUTER_API_KEY')
OPENROUTER_BASE = "https://openrouter.ai/api/v1"
llm = ChatOpenAI(model="stepfun/step-3.5-flash:free", api_key=OPENROUTER_API, base_url=OPENROUTER_BASE)

# %%
from langchain_core
prompt =

# %%
from langchain_core.output_parsers import StrOutputParser


rag_chain = prompt | llm | StrOutputParser()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 from langchain_core.output_parsers import StrOutputParser
# ----> 4 rag_chain = query | llm | StrOutputParser()
#
# NameError: name 'query' is not defined
